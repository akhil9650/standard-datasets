# %%
#importing packages
# %matplotlib inline
import scipy.stats as stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/creditcard.csv')

# %%
X = df.drop('Class', axis=1)
Y = df['Class']

# %%
# split data into train and test sets
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
# fit model no training data
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# %%
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 99.96%

# %%
eval_set = [(X_train, y_train), (X_test, y_test)]
eval_metric = ["auc","error"]
# %time model.fit(X_train, y_train, eval_metric=eval_metric, eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-auc:0.904684	validation_0-error:0.000697	validation_1-auc:0.933557	validation_1-error:0.000606
# [1]	validation_0-auc:0.904684	validation_0-error:0.000692	validation_1-auc:0.933557	validation_1-error:0.000606
# [2]	validation_0-auc:0.904713	validation_0-error:0.000707	validation_1-auc:0.933582	validation_1-error:0.000575
# [3]	validation_0-auc:0.904714	validation_0-error:0.000692	validation_1-auc:0.933585	validation_1-error:0.000553
# [4]	validation_0-auc:0.904715	validation_0-error:0.000681	validation_1-auc:0.933584	validation_1-error:0.000543
# [5]	validation_0-auc:0.91234	validation_0-error:0.000697	validation_1-auc:0.94259	validation_1-error:0.000553
# [6]	validation_0-auc:0.912346	validation_0-error:0.000676	validation_1-auc:0.942592	validation_1-error:0.000564
# [7]	validation_0-auc:0.912346	validation_0-error:0.000671	validation_1-auc:0.942596	validation_1-error:0.000553
# [8]	validation_0-auc:0.912364	validation_0-error:0.000666	validation_1-auc:0.942609	validation_1-error:0.000543
# [9]	validation_0-auc:0.912367	validation_0-error:0.000666	validation_1-auc:0.94261	validation_1-error:0.000564
# [10]	validation_0-auc:0.912376	validation_0-error:0.000666	validation_1-auc:0.942611	validation_1-error:0.000553
# [11]	validation_0-auc:0.912377	validation_0-error:0.000666	validation_1-auc:0.942612	validation_1-error:0.000553
# [12]	validation_0-auc:0.912384	validation_0-error:0.000666	validation_1-auc:0.942619	validation_1-error:0.000553
# [13]	validation_0-auc:0.912391	validation_0-error:0.000655	validation_1-auc:0.94263	validation_1-error:0.000521
# [14]	validation_0-auc:0.912392	validation_0-error:0.000618	validation_1-auc:0.942636	validation_1-error:0.0005
# [15]	validation_0-auc:0.912397	validation_0-error:0.000613	validation_1-auc:0.942641	validation_1-error:0.000489
# [16]	validation_0-auc:0.9124	validation_0-error:0.000603	validation_1-auc:0.942645	validation_1-error:0.0005
# [17]	validation_0-auc:0.913926	validation_0-error:0.000608	validation_1-auc:0.94264	validation_1-error:0.000489
# [18]	validation_0-auc:0.913927	validation_0-error:0.000603	validation_1-auc:0.942642	validation_1-error:0.0005
# [19]	validation_0-auc:0.913929	validation_0-error:0.000603	validation_1-auc:0.942643	validation_1-error:0.000479
# [20]	validation_0-auc:0.91393	validation_0-error:0.000582	validation_1-auc:0.942644	validation_1-error:0.000468
# [21]	validation_0-auc:0.913931	validation_0-error:0.000571	validation_1-auc:0.942644	validation_1-error:0.000468
# [22]	validation_0-auc:0.913933	validation_0-error:0.000555	validation_1-auc:0.942646	validation_1-error:0.000458
# [23]	validation_0-auc:0.915422	validation_0-error:0.00054	validation_1-auc:0.942615	validation_1-error:0.000468
# [24]	validation_0-auc:0.915423	validation_0-error:0.000545	validation_1-auc:0.942615	validation_1-error:0.000479
# [25]	validation_0-auc:0.915424	validation_0-error:0.000524	validation_1-auc:0.942615	validation_1-error:0.000468
# [26]	validation_0-auc:0.916914	validation_0-error:0.000519	validation_1-auc:0.942584	validation_1-error:0.000468
# [27]	validation_0-auc:0.916914	validation_0-error:0.000451	validation_1-auc:0.942585	validation_1-error:0.000404
# [28]	validation_0-auc:0.916919	validation_0-error:0.000451	validation_1-auc:0.942585	validation_1-error:0.000394
# [29]	validation_0-auc:0.919896	validation_0-error:0.000445	validation_1-auc:0.942526	validation_1-error:0.000404
# [30]	validation_0-auc:0.91988	validation_0-error:0.000445	validation_1-auc:0.942515	validation_1-error:0.000415
# [31]	validation_0-auc:0.945409	validation_0-error:0.000445	validation_1-auc:0.95501	validation_1-error:0.000415
# [32]	validation_0-auc:0.946955	validation_0-error:0.000445	validation_1-auc:0.957694	validation_1-error:0.000394
# [33]	validation_0-auc:0.946956	validation_0-error:0.00044	validation_1-auc:0.957691	validation_1-error:0.000404
# [34]	validation_0-auc:0.946956	validation_0-error:0.00044	validation_1-auc:0.958229	validation_1-error:0.000404
# [35]	validation_0-auc:0.946936	validation_0-error:0.000435	validation_1-auc:0.958221	validation_1-error:0.000415
# [36]	validation_0-auc:0.946934	validation_0-error:0.00043	validation_1-auc:0.95822	validation_1-error:0.000426
# [37]	validation_0-auc:0.95454	validation_0-error:0.000409	validation_1-auc:0.962619	validation_1-error:0.000426
# [38]	validation_0-auc:0.954554	validation_0-error:0.000409	validation_1-auc:0.962615	validation_1-error:0.000426
# [39]	validation_0-auc:0.95968	validation_0-error:0.000409	validation_1-auc:0.967876	validation_1-error:0.000415
# [40]	validation_0-auc:0.966185	validation_0-error:0.000404	validation_1-auc:0.970127	validation_1-error:0.000415
# [41]	validation_0-auc:0.966244	validation_0-error:0.000398	validation_1-auc:0.970143	validation_1-error:0.000436
# [42]	validation_0-auc:0.96619	validation_0-error:0.000404	validation_1-auc:0.970102	validation_1-error:0.000415
# [43]	validation_0-auc:0.966481	validation_0-error:0.000388	validation_1-auc:0.970027	validation_1-error:0.000415
# [44]	validation_0-auc:0.966464	validation_0-error:0.000388	validation_1-auc:0.969991	validation_1-error:0.000415
# [45]	validation_0-auc:0.966528	validation_0-error:0.000388	validation_1-auc:0.97007	validation_1-error:0.000404
# [46]	validation_0-auc:0.96681	validation_0-error:0.000393	validation_1-auc:0.97052	validation_1-error:0.000404
# [47]	validation_0-auc:0.967231	validation_0-error:0.000393	validation_1-auc:0.970702	validation_1-error:0.000404
# [48]	validation_0-auc:0.967379	validation_0-error:0.000393	validation_1-auc:0.970708	validation_1-error:0.000404
# [49]	validation_0-auc:0.967421	validation_0-error:0.000393	validation_1-auc:0.970617	validation_1-error:0.000404
# [50]	validation_0-auc:0.970399	validation_0-error:0.000393	validation_1-auc:0.9706	validation_1-error:0.000404
# [51]	validation_0-auc:0.970772	validation_0-error:0.000393	validation_1-auc:0.970551	validation_1-error:0.000404
# [52]	validation_0-auc:0.971152	validation_0-error:0.000393	validation_1-auc:0.970789	validation_1-error:0.000404
# [53]	validation_0-auc:0.971378	validation_0-error:0.000393	validation_1-auc:0.970981	validation_1-error:0.000404
# [54]	validation_0-auc:0.97261	validation_0-error:0.000377	validation_1-auc:0.973555	validation_1-error:0.000404
# [55]	validation_0-auc:0.973888	validation_0-error:0.000377	validation_1-auc:0.976086	validation_1-error:0.000404
# [56]	validation_0-auc:0.974096	validation_0-error:0.000362	validation_1-auc:0.97601	validation_1-error:0.000404
# [57]	validation_0-auc:0.974487	validation_0-error:0.000362	validation_1-auc:0.975976	validation_1-error:0.000404
# [58]	validation_0-auc:0.974714	validation_0-error:0.000362	validation_1-auc:0.975968	validation_1-error:0.000415
# [59]	validation_0-auc:0.974925	validation_0-error:0.000362	validation_1-auc:0.975845	validation_1-error:0.000415
# [60]	validation_0-auc:0.974974	validation_0-error:0.000362	validation_1-auc:0.976163	validation_1-error:0.000415
# [61]	validation_0-auc:0.975071	validation_0-error:0.000362	validation_1-auc:0.9761	validation_1-error:0.000404
# [62]	validation_0-auc:0.978636	validation_0-error:0.000362	validation_1-auc:0.978046	validation_1-error:0.000426
# [63]	validation_0-auc:0.979652	validation_0-error:0.000362	validation_1-auc:0.977763	validation_1-error:0.000415
# [64]	validation_0-auc:0.983966	validation_0-error:0.000362	validation_1-auc:0.978718	validation_1-error:0.000415
# [65]	validation_0-auc:0.983794	validation_0-error:0.000362	validation_1-auc:0.978609	validation_1-error:0.000404
# [66]	validation_0-auc:0.983913	validation_0-error:0.000362	validation_1-auc:0.978569	validation_1-error:0.000415
# [67]	validation_0-auc:0.984034	validation_0-error:0.000362	validation_1-auc:0.978109	validation_1-error:0.000426
# [68]	validation_0-auc:0.987759	validation_0-error:0.000362	validation_1-auc:0.984854	validation_1-error:0.000426
# [69]	validation_0-auc:0.990358	validation_0-error:0.000362	validation_1-auc:0.984409	validation_1-error:0.000436
# [70]	validation_0-auc:0.99025	validation_0-error:0.000362	validation_1-auc:0.984592	validation_1-error:0.000436
# [71]	validation_0-auc:0.990383	validation_0-error:0.000362	validation_1-auc:0.984197	validation_1-error:0.000436
# [72]	validation_0-auc:0.991441	validation_0-error:0.000356	validation_1-auc:0.985369	validation_1-error:0.000426
# [73]	validation_0-auc:0.991396	validation_0-error:0.000356	validation_1-auc:0.985037	validation_1-error:0.000436
# [74]	validation_0-auc:0.991554	validation_0-error:0.000356	validation_1-auc:0.984296	validation_1-error:0.000436
# [75]	validation_0-auc:0.992579	validation_0-error:0.000356	validation_1-auc:0.985494	validation_1-error:0.000436
# [76]	validation_0-auc:0.992751	validation_0-error:0.000356	validation_1-auc:0.986556	validation_1-error:0.000436
# [77]	validation_0-auc:0.993402	validation_0-error:0.000356	validation_1-auc:0.986838	validation_1-error:0.000426
# [78]	validation_0-auc:0.993785	validation_0-error:0.000362	validation_1-auc:0.987277	validation_1-error:0.000436
# [79]	validation_0-auc:0.994095	validation_0-error:0.000362	validation_1-auc:0.987511	validation_1-error:0.000436
# [80]	validation_0-auc:0.994184	validation_0-error:0.000362	validation_1-auc:0.987211	validation_1-error:0.000436
# [81]	validation_0-auc:0.994412	validation_0-error:0.000362	validation_1-auc:0.988322	validation_1-error:0.000436
# [82]	validation_0-auc:0.994727	validation_0-error:0.000362	validation_1-auc:0.988341	validation_1-error:0.000436
# [83]	validation_0-auc:0.994968	validation_0-error:0.000362	validation_1-auc:0.988371	validation_1-error:0.000436
# [84]	validation_0-auc:0.995162	validation_0-error:0.000362	validation_1-auc:0.988409	validation_1-error:0.000436
# [85]	validation_0-auc:0.995477	validation_0-error:0.000362	validation_1-auc:0.988739	validation_1-error:0.000436
# [86]	validation_0-auc:0.995594	validation_0-error:0.000362	validation_1-auc:0.988865	validation_1-error:0.000436
# [87]	validation_0-auc:0.995779	validation_0-error:0.000362	validation_1-auc:0.988616	validation_1-error:0.000426
# [88]	validation_0-auc:0.995885	validation_0-error:0.000362	validation_1-auc:0.989134	validation_1-error:0.000426
# [89]	validation_0-auc:0.996	validation_0-error:0.000362	validation_1-auc:0.989182	validation_1-error:0.000426
# [90]	validation_0-auc:0.996063	validation_0-error:0.000356	validation_1-auc:0.988767	validation_1-error:0.000415
# [91]	validation_0-auc:0.996239	validation_0-error:0.000356	validation_1-auc:0.989105	validation_1-error:0.000415
# [92]	validation_0-auc:0.99634	validation_0-error:0.000362	validation_1-auc:0.988911	validation_1-error:0.000415
# [93]	validation_0-auc:0.996463	validation_0-error:0.000356	validation_1-auc:0.98907	validation_1-error:0.000415
# [94]	validation_0-auc:0.996505	validation_0-error:0.000351	validation_1-auc:0.989589	validation_1-error:0.000415
# [95]	validation_0-auc:0.996526	validation_0-error:0.000351	validation_1-auc:0.989558	validation_1-error:0.000415
# [96]	validation_0-auc:0.996643	validation_0-error:0.000351	validation_1-auc:0.989789	validation_1-error:0.000415
# [97]	validation_0-auc:0.996683	validation_0-error:0.000346	validation_1-auc:0.989611	validation_1-error:0.000415
# [98]	validation_0-auc:0.99672	validation_0-error:0.000346	validation_1-auc:0.989031	validation_1-error:0.000415
# [99]	validation_0-auc:0.996792	validation_0-error:0.000346	validation_1-auc:0.98918	validation_1-error:0.000415
# CPU times: user 1min 1s, sys: 266 ms, total: 1min 2s
# Wall time: 1min 2s
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
import pandas as pd
import numpy as np
from pylab import rcParams
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)
SEED = 123 #used to help randomly select the data points
DATA_SPLIT_PCT = 0.2
rcParams['figure.figsize'] = 8, 6
LABELS = ["Normal","Break"]
# Out:
# Using TensorFlow backend.

# %%
sign = lambda x: (1, -1)[x < 0]

def curve_shift(df, shift_by):
    '''
    This function will shift the binary labels in a dataframe.
    The curve shift will be with respect to the 1s. 
    For example, if shift is -2, the following process
    will happen: if row n is labeled as 1, then
    - Make row (n+shift_by):(n+shift_by-1) = 1.
    - Remove row n.
    i.e. the labels will be shifted up to 2 rows up.
    
    Inputs:
    df       A pandas dataframe with a binary labeled column. 
             This labeled column should be named as 'y'.
    shift_by An integer denoting the number of rows to shift.
    
    Output
    df       A dataframe with the binary labels shifted by shift.
    '''

    vector = df['y'].copy()
    for s in range(abs(shift_by)):
        tmp = vector.shift(sign(shift_by))
        tmp = tmp.fillna(0)
        vector += tmp
    labelcol = 'y'
    # Add vector to the df
    df.insert(loc=0, column=labelcol+'tmp', value=vector)
    # Remove the rows with labelcol == 1.
    df = df.drop(df[df[labelcol] == 1].index)
    # Drop labelcol and rename the tmp col as labelcol
    df = df.drop(labelcol, axis=1)
    df = df.rename(columns={labelcol+'tmp': labelcol})
    # Make the labelcol binary
    df.loc[df[labelcol] > 0, labelcol] = 1

    return df

# %%
df_train, df_test = train_test_split(df, test_size=DATA_SPLIT_PCT, random_state=SEED)
df_train, df_valid = train_test_split(df_train, test_size=DATA_SPLIT_PCT, random_state=SEED)
df_train_0 = df_train.loc[df['y'] == 0]
df_train_1 = df_train.loc[df['y'] == 1]
df_train_0_x = df_train_0.drop(['y'], axis=1)
df_train_1_x = df_train_1.drop(['y'], axis=1)
df_valid_0 = df_valid.loc[df['y'] == 0]
df_valid_1 = df_valid.loc[df['y'] == 1]
df_valid_0_x = df_valid_0.drop(['y'], axis=1)
df_valid_1_x = df_valid_1.drop(['y'], axis=1)
df_test_0 = df_test.loc[df['y'] == 0]
df_test_1 = df_test.loc[df['y'] == 1]
df_test_0_x = df_test_0.drop(['y'], axis=1)
df_test_1_x = df_test_1.drop(['y'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-1642e55ffdc4> in <module>()
#       1 df_train, df_test = train_test_split(df, test_size=DATA_SPLIT_PCT, random_state=SEED)
#       2 df_train, df_valid = train_test_split(df_train, test_size=DATA_SPLIT_PCT, random_state=SEED)
# ----> 3 df_train_0 = df_train.loc[df['y'] == 0]
#       4 df_train_1 = df_train.loc[df['y'] == 1]
#       5 df_train_0_x = df_train_0.drop(['y'], axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y'
